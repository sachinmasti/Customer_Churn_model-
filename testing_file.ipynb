# %%
import pandas as pd

# %%
df = pd.read_csv('data/customer_churn_v2.0_clean.csv')

# %%
df.head()
# Out:
#     age  gender location  tenure_months  monthly_charges  total_charges  \
# 0  34.0  female    other      35.719310        40.957227    1462.963855
# 1  59.0  female    other       0.296729        86.060468      25.536674
# 2  49.0   other    other      59.780234        43.665558    2610.337280
# 3  25.0     NaN    other      69.575193        54.225069    3772.719616
# 4  53.0    male    other       2.320422        93.224375     216.319920
#
#   contract_type internet_service phone_service online_security  ... churn  \
# 0       monthly      no internet            no              no  ...    no
# 1        1 year      fiber optic           yes             yes  ...   yes
# 2       monthly      no internet           yes              no  ...    no
# 3        1 year              dsl            no             yes  ...    no
# 4       monthly      fiber optic           yes             yes  ...   yes
#
#   satisfaction_score support_tickets  last_contact_day  last_contact_month  \
# ...

# %%
df['payment_method'].value_counts()
# Out:
# payment_method
# electronic check             7127
# credit card (automatic)      4434
# mailed check                 4244
# bank transfer (automatic)    4038
# upi                           102
# cash                           98
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'gender', 'location', 'tenure_months', 'monthly_charges',
#        'total_charges', 'contract_type', 'internet_service', 'phone_service',
#        'online_security', 'tech_support', 'payment_method', 'churn',
#        'satisfaction_score', 'support_tickets', 'last_contact_day',
#        'last_contact_month', 'last_contact_year', 'last_contact_week',
#        'last_contact_week_of_year', 'valid_email', 'email_domain'],
#       dtype='str')

# %%
df['last_contact_week']
# Out:
# 0        NaN
# 1        2.0
# 2        0.0
# 3        6.0
# 4        NaN
#         ...
# 20256    5.0
# 20257    NaN
# 20258    1.0
# 20259    5.0
# 20260    3.0
# Name: last_contact_week, Length: 20261, dtype: float64
